# %%
import pandas as pd

data = pd.read_csv('WHO-COVID-19-global-data.csv')
data.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
data.shape
# Out:
# (144096, 8)

# %%
print('A Base de dados inicia em: {} e termina em: {}'.format(data.Date_reported.min(), data.Date_reported.max()))
# Out:
# A Base de dados inicia em: 2020-01-03 e termina em: 2021-09-01

# %%
data['Country']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 144091       Zimbabwe
# 144092       Zimbabwe
# 144093       Zimbabwe
# 144094       Zimbabwe
# 144095       Zimbabwe
# Name: Country, Length: 144096, dtype: object

# %%
data['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
data["WHO_region"].unique()
# Out:
# array(['EMRO', 'EURO', 'AFRO', 'WPRO', 'AMRO', 'SEARO', 'Other'],
#       dtype=object)

# %%
data.sample(20)
# Out:
#        Date_reported Country_code                           Country  \
# 42177     2020-08-15           FO                     Faroe Islands
# 23479     2021-01-12           KY                    Cayman Islands
# 59848     2020-09-23           IR        Iran (Islamic Republic of)
# 112479    2021-09-01           VC  Saint Vincent and the Grenadines
# 119821    2020-02-17           SI                          Slovenia
# 98824     2020-11-26           PG                  Papua New Guinea
# 116344    2020-08-06           SC                        Seychelles
# 28907     2020-11-29           CR                        Costa Rica
# 10231     2021-05-20           BD                        Bangladesh
# 134972    2021-08-29           TV                            Tuvalu
# 68030     2021-06-28           XK                         Kosovo[1]
# 8590      2020-03-21           BS                           Bahamas
# 120282    2021-05-23           SI                          Slovenia
# ...

# %%
data.iloc[1]
# Out:
# Date_reported         2020-01-04
# Country_code                  AF
# Country              Afghanistan
# WHO_region                  EMRO
# New_cases                      0
# Cumulative_cases               0
# New_deaths                     0
# Cumulative_deaths              0
# Name: 1, dtype: object

# %%
data.set_index('Country').loc['Brazil']
# Out:
#         Date_reported Country_code WHO_region  New_cases  Cumulative_cases  \
# Country
# Brazil     2020-01-03           BR       AMRO          0                 0
# Brazil     2020-01-04           BR       AMRO          0                 0
# Brazil     2020-01-05           BR       AMRO          0                 0
# Brazil     2020-01-06           BR       AMRO          0                 0
# Brazil     2020-01-07           BR       AMRO          0                 0
# ...               ...          ...        ...        ...               ...
# Brazil     2021-08-28           BR       AMRO      31024          20676561
# Brazil     2021-08-29           BR       AMRO      27345          20703906
# Brazil     2021-08-30           BR       AMRO      24699          20728605
# Brazil     2021-08-31           BR       AMRO      13210          20741815
# Brazil     2021-09-01           BR       AMRO      10466          20752281
#
#          New_deaths  Cumulative_deaths
# Country
# ...

# %%
data.set_index('Country').iloc[1]
# Out:
# Date_reported        2020-01-04
# Country_code                 AF
# WHO_region                 EMRO
# New_cases                     0
# Cumulative_cases              0
# New_deaths                    0
# Cumulative_deaths             0
# Name: Afghanistan, dtype: object

# %%
# valor falso pois o erro é muito grande
# não vou considerar essa analise pois tem muito campo vazio (muita disparidade no padrão)

data['Country'].value_counts()
# Out:
# China                          608
# Australia                      608
# Saba                           608
# Martinique                     608
# Qatar                          608
#                               ...
# Malta                          608
# Falkland Islands (Malvinas)    608
# Jersey                         608
# Nigeria                        608
# Comoros                        608
# Name: Country, Length: 237, dtype: int64

# %%
data_by_country = data.groupby('Country', as_index=False).sum()
data_by_country.head()
# Out:
#           Country  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 0     Afghanistan     153260          29127734        7123            1196741
# 1         Albania     146387          32384518        2498             607199
# 2         Algeria     196080          42472291        5269            1219709
# 3  American Samoa          0                 0           0                  0
# 4         Andorra      15033           3728191         130              44127

# %%
data_by_country.sample(10)
# Out:
#            Country  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 16      Bangladesh    1500618         267074339       26195            4109790
# 73   French Guiana      35073           7154930         219              40028
# 15         Bahrain     272540          58864954        1388             248728
# 110       Kiribati          0                 0           0                  0
# 231       Viet Nam     462092          11983352       11064             215995
# 93        Honduras     338757          67368289        8850            1774914
# 185     San Marino       5331           1340515          90              32177
# 196       Slovenia     267198          59885716        4779            1197645
# 36        Cameroon      84210          18928486        1357             322211
# 86       Guatemala     465799          76641477       11886            2489832

# %%
data_by_country.query("Country == 'Brazil'")
# Out:
#    Country  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 28  Brazil   20752281        4424304303      579574          122113749

# %%
import matplotlib.pyplot as plt

# grafico extremamente apertado
# estamos sendo longe do adequado ao passar uma mensagem errada

fig = plt.figure(figsize=(2,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.query("Country == 'Brazil'").plot(x='Date_reported', y='Cumulative_cases', ax=ax1)
ax1.set_title('Cumulative Cases on Brazil')
# Out:
# Text(0.5, 1.0, 'Cumulative Cases on Brazil')

# %% [markdown]
# Nos últimos 20 dias desses dados, DOBROU os casos confirmados

# %%
# por isso em data visualization é FUNDAMENTAL
# estarmos atentos aos DOIS EIXOS
# esse aqui esta tentando comparar o crescimento do momento inicial ao momento atual

fig = plt.figure(figsize=(10,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.query("Country == 'Brazil'").plot(x='Date_reported', y='Cumulative_cases', ax=ax1)
ax1.set_title('Cumulative Cases on Brazil')
# Out:
# Text(0.5, 1.0, 'Cumulative Cases on Brazil')

# %%
# exemplo ruim de manusear o eixo y
# aqui a mensagem ficou novamente diferente

# esse aqui esta tentando comparar o momento inicial com 212 milhões (populacao do Brasil em 2021)
# aqui a mensagem eh novamente completamente diferente
# e pode ser uma mensagem ruim, ate mesmo errada. poderai ser uma doenca grave
# mas ao usarmos o eixo y com a populacao geral, fingimos que ela nao eh grave
# sendo que na realidade ESSE grafico nao POSSUI INFORMACAO NENHUMA sobre a gravidade
# da doenca

# pq? so tem caso confirmado. nao fala letalidade? nao fala incidencia?
# quais sao as provincias infectadas? sao de toda a china? e estou comparando com a
# populacao de toda a china. errado.


fig = plt.figure(figsize=(10,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.query("Country == 'Brazil'").plot(x='Date_reported', y='Cumulative_cases', ax=ax1)
ax1.set_title('Novos Casos no Brasil')
ax1.set_ylim(0, 211000000)
ax1.set_title("Gráfico errado. Passa uma mensagem errada, com comparações injustas.")
# Out:
# Text(0.5, 1.0, 'Gráfico errado. Passa uma mensagem errada, com comparações injustas.')

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.query("Country == 'Brazil'").plot(x='Date_reported', y='New_cases', ax=ax1)
ax1.set_title('New Cases in Brasil')
# Out:
# Text(0.5, 1.0, 'New Cases in Brasil')

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.groupby('Country').max().plot(y='Cumulative_cases', ax=ax1)
ax1.set_title('Cumulative by Country')
# Out:
# Text(0.5, 1.0, 'Cumulative by Country')

# %%
plt.figure(figsize=(10,5))

# 99.99% das vezes não devemos usar grafico de pizza e torta
# "se o nome do gráfico tem comida no meio, não use" (boa pratica)

# 1. muitas categorias inviavel
# 2. poucas categorias, a comparacao eh de area!!!


# ah, mas cai no 0.01% que eh pra usar torta/pizza
# não, não caiu. pense novamente. se acredita que sim. pense novamente
# se acrdita que sim, assuma os riscos

data.query("Date_reported == '2021-09-01'")['Cumulative_cases'].plot(kind='pie')
plt.title("Confirmados por país")
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.groupby('Country').max()[0:10].plot(y='Cumulative_cases', kind='bar', ax=ax1)
ax1.set_title('Cumulative by Country')
# Out:
# Text(0.5, 1.0, 'Cumulative by Country')

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_axes([0, 0, 1, 1])
data.groupby('Country').max().sort_values(ascending=False, by='Cumulative_cases')[0:10].plot(y='Cumulative_cases', kind='bar', ax=ax1)
ax1.set_title('Cumulative by Country')
# Out:
# Text(0.5, 1.0, 'Cumulative by Country')

# %%
filtered = data.query("Date_reported == '2021-09-01'")[['Date_reported', 'Country', 'Cumulative_cases','Cumulative_deaths']]

# %%
# taxa de letalidade é expressa em %
# o número de casos letais dentro dos casos que foram letais e não letais

# imagina que existe uma doença que em janeiro de 2020 afetou 100 pessoas
# 5 pessoas morreram (por exemplo). letalidade foi de 5%.
# não digo que ela É de 5% para sempre pq a doença continuou existindo

# conclusão é MUITO dificil de falar de letalidade tentando ser preciso
# durante uma epidemia

# no começo é comum que somente casos graves sejam reportados

# %%
sum_up = filtered.sum()
letality_rate = sum_up['Cumulative_deaths'] / sum_up["Cumulative_cases"]
print(letality_rate * 100)
# Out:
# 2.0763309055464374

# %%
filtered['letality_rate'] = filtered['Cumulative_deaths'] / filtered["Cumulative_cases"]
filtered[['Country','Cumulative_cases', 'letality_rate']].plot(x='Country')
#filtered['Cumulative_cases'].plot()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
import seaborn as sns

sns.scatterplot(data = filtered, x="Cumulative_cases", y="letality_rate")
# Out:
# <AxesSubplot:xlabel='Cumulative_cases', ylabel='letality_rate'>

# %%
sns.scatterplot(data = filtered.query("Cumulative_cases > 40 and Cumulative_cases < 50000"), x="Cumulative_cases", y="letality_rate")
# Out:
# <AxesSubplot:xlabel='Cumulative_cases', ylabel='letality_rate'>

# %%
sns.scatterplot(data = filtered.query("Cumulative_cases > 40"), x="Cumulative_cases", y="letality_rate")
# Out:
# <AxesSubplot:xlabel='Cumulative_cases', ylabel='letality_rate'>

# %%
sns.distplot(filtered.query("Cumulative_cases > 40")["letality_rate"], kde=False)
# Out:
# /home/diego/.local/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='letality_rate'>

# %%
filtered.sort_values("letality_rate", ascending=False).query("Cumulative_cases > 40").head(10)
# Out:
#        Date_reported               Country  Cumulative_cases  \
# 142879    2021-09-01                 Yemen              7869
# 100319    2021-09-01                  Peru           2149591
# 82079     2021-09-01                Mexico           3341264
# 124639    2021-09-01                 Sudan             37709
# 127071    2021-09-01  Syrian Arab Republic             27915
# 37087     2021-09-01               Ecuador            501201
# 37695     2021-09-01                 Egypt            288441
# 121599    2021-09-01               Somalia             17466
# 607       2021-09-01           Afghanistan            153260
# 26143     2021-09-01                 China            123068
#
#         Cumulative_deaths  letality_rate
# 142879               1472       0.187063
# 100319             198263       0.092233
# 82079              258491       0.077363
# 124639               2791       0.074014
# 127071               2013       0.072112
# 37087               32244       0.064333
# ...

# %% [markdown]
# # Segunda Parte - Data Visualization

# %%
data
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 144091    2021-08-28           ZW     Zimbabwe       AFRO        250
# 144092    2021-08-29           ZW     Zimbabwe       AFRO        131
# 144093    2021-08-30           ZW     Zimbabwe       AFRO         70
# 144094    2021-08-31           ZW     Zimbabwe       AFRO        144
# 144095    2021-09-01           ZW     Zimbabwe       AFRO        192
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
data.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
data_03_03 = data.query("Date_reported <= '2020-03-03' & Date_reported >= '2020-01-23'")
data_03_03.head()
# Out:
#    Date_reported Country_code      Country WHO_region  New_cases  \
# 20    2020-01-23           AF  Afghanistan       EMRO          0
# 21    2020-01-24           AF  Afghanistan       EMRO          0
# 22    2020-01-25           AF  Afghanistan       EMRO          0
# 23    2020-01-26           AF  Afghanistan       EMRO          0
# 24    2020-01-27           AF  Afghanistan       EMRO          0
#
#     Cumulative_cases  New_deaths  Cumulative_deaths
# 20                 0           0                  0
# 21                 0           0                  0
# 22                 0           0                  0
# 23                 0           0                  0
# 24                 0           0                  0

# %%
is_China = data_03_03['Country'].isin(['China'])
data_03_03['is_China'] = is_China
data_03_03.head()

data_03_03.query('is_China == True').head()
# Out:
# <ipython-input-35-c2ebe3cf8639>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_03_03['is_China'] = is_China
#       Date_reported Country_code Country WHO_region  New_cases  \
# 25556    2020-01-23           CN   China       WPRO        132
# 25557    2020-01-24           CN   China       WPRO        261
# 25558    2020-01-25           CN   China       WPRO        462
# 25559    2020-01-26           CN   China       WPRO        688
# 25560    2020-01-27           CN   China       WPRO        776
#
#        Cumulative_cases  New_deaths  Cumulative_deaths  is_China
# 25556               574           1                 18      True
# 25557               835           8                 26      True
# ...

# %%
data_03_03.groupby('is_China').sum()
# Out:
#           New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# is_China
# False         10920             65393         179                841
# True          79860           1873281        2931              56039

# %%
data_03_03.groupby('is_China').sum().plot(kind ='pie', y='New_cases')
# Out:
# <AxesSubplot:ylabel='New_cases'>

# %%
data_03_03.groupby('is_China').sum().plot(kind ='bar', y='New_cases')
# Out:
# <AxesSubplot:xlabel='is_China'>

# %% [markdown]
# ## No dia 02/03/2020 a China tinha aproximadamente o número de casos, contudo isso é injusto pois estamos resumindo as informações e com isso perdendo elas.
#
# Mas olhar uma fotografia é muito limitado, também queremos ver como anda o crescimento.

# %%
import numpy as np
data_03_03['is_china_label'] = np.where(data_03_03['is_China'], 'China', 'Others')
display(data_03_03.head())
display(data_03_03.tail())
# Out:
# <ipython-input-39-1acd26e8986a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_03_03['is_china_label'] = np.where(data_03_03['is_China'], 'China', 'Others')
#    Date_reported Country_code      Country WHO_region  New_cases  \
# 20    2020-01-23           AF  Afghanistan       EMRO          0
# 21    2020-01-24           AF  Afghanistan       EMRO          0
# 22    2020-01-25           AF  Afghanistan       EMRO          0
# 23    2020-01-26           AF  Afghanistan       EMRO          0
# 24    2020-01-27           AF  Afghanistan       EMRO          0
#
#     Cumulative_cases  New_deaths  Cumulative_deaths  is_China is_china_label
# 20                 0           0                  0     False         Others
# ...

# %%
data_03_03.groupby('is_china_label').sum().plot(kind ='bar', y='New_cases')
plt.title('Casos Confirmados Acumulados até 03/02/2020')
# Out:
# Text(0.5, 1.0, 'Casos Confirmados Acumulados até 03/02/2020')

# %%
data_03_03.query("Date_reported == '2020-03-03'").groupby('is_china_label').sum().plot(kind ='bar',y='New_cases')
plt.title('Novos casos em 03/02/2020')
# Out:
# Text(0.5, 1.0, 'Novos casos em 03/02/2020')

# %%
sns.lineplot(x='Date_reported', y='Cumulative_cases', hue='is_china_label', data=data_03_03)
# Out:
# <AxesSubplot:xlabel='Date_reported', ylabel='Cumulative_cases'>

# %%
sns.lineplot(x='Date_reported', y='New_cases', hue='is_china_label', data=data_03_03)
# Out:
# <AxesSubplot:xlabel='Date_reported', ylabel='New_cases'>

# %%
cases = data_03_02.groupby('is_china_label').sum().loc['China']['New_cases']
estimated_population = 1437525528
incidence_ratio = cases / estimated_population * 100000
print(incidence_ratio)

# conta péssima, ruim e errada, pois estamos usando uma população muito maior do que 
# deveria estar usando
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-f0f4f1053639> in <module>
# ----> 1 cases = data_03_02.groupby('is_china_label').sum().loc['China']['New_cases']
#       2 estimated_population = 1437525528
#       3 incidence_ratio = cases / estimated_population * 100000
#       4 print(incidence_ratio)
#       5
#
# NameError: name 'data_03_02' is not defined

# %%
un_population = pd.read_csv('WPP2019_TotalPopulationBySex.csv')
un_population.head()
# Out:
#    LocID     Location  VarID Variant  Time  MidPeriod   PopMale  PopFemale  \
# 0      4  Afghanistan      2  Medium  1950     1950.5  4099.243   3652.874
# 1      4  Afghanistan      2  Medium  1951     1951.5  4134.756   3705.395
# 2      4  Afghanistan      2  Medium  1952     1952.5  4174.450   3761.546
# 3      4  Afghanistan      2  Medium  1953     1953.5  4218.336   3821.348
# 4      4  Afghanistan      2  Medium  1954     1954.5  4266.484   3884.832
#
#    PopTotal  PopDensity
# 0  7752.117      11.874
# 1  7840.151      12.009
# 2  7935.996      12.156
# 3  8039.684      12.315
# 4  8151.316      12.486

# %%
un_population.describe()
# Out:
#                LocID          VarID           Time      MidPeriod  \
# count  280932.000000  280932.000000  280932.000000  280932.000000
# mean      703.125062      22.411345    2051.026494    2051.526494
# std       631.959759      55.972847      33.642148      33.642148
# min         4.000000       2.000000    1950.000000    1950.500000
# 25%       300.000000       2.000000    2031.000000    2031.500000
# 50%       586.000000       5.000000    2055.000000    2055.500000
# 75%       903.000000       9.000000    2078.000000    2078.500000
# max      5501.000000     207.000000    2100.000000    2100.500000
#
#             PopMale     PopFemale      PopTotal     PopDensity
# count  2.508760e+05  2.508760e+05  2.809320e+05  280932.000000
# mean   2.324362e+05  2.298754e+05  4.128536e+05     426.659040
# std    6.938837e+05  6.829825e+05  1.308911e+06    2418.990784
# min    6.812000e+00  6.889000e+00  1.510000e-01       0.052000
# ...

# %%
un_population.query('Time == 2019').head()
# Out:
#       LocID                       Location  VarID Variant  Time  MidPeriod  \
# 69        4                    Afghanistan      2  Medium  2019     2019.5
# 953     903                         Africa      2  Medium  2019     2019.5
# 1837   1823                  African Group      2  Medium  2019     2019.5
# 1988   1560                  African Union      2  Medium  2019     2019.5
# 2139   2080  African Union: Central Africa      2  Medium  2019     2019.5
#
#          PopMale   PopFemale     PopTotal  PopDensity
# 69     19529.727   18512.030    38041.757      58.269
# 953   653513.680  654550.496  1308064.176      44.119
# 1837  652644.714  653675.858  1306320.572      44.464
# 1988  652949.469  653953.561  1306903.030      44.085
# 2139   76945.498   77068.207   154013.705      29.192

# %%
un_population['PopTotal'] = un_population['PopTotal'] * 1000
un_population.head()
# Out:
#    LocID     Location  VarID Variant  Time  MidPeriod   PopMale  PopFemale  \
# 0      4  Afghanistan      2  Medium  1950     1950.5  4099.243   3652.874
# 1      4  Afghanistan      2  Medium  1951     1951.5  4134.756   3705.395
# 2      4  Afghanistan      2  Medium  1952     1952.5  4174.450   3761.546
# 3      4  Afghanistan      2  Medium  1953     1953.5  4218.336   3821.348
# 4      4  Afghanistan      2  Medium  1954     1954.5  4266.484   3884.832
#
#     PopTotal  PopDensity
# 0  7752117.0      11.874
# 1  7840151.0      12.009
# 2  7935996.0      12.156
# 3  8039684.0      12.315
# 4  8151316.0      12.486

# %%
data_03_03.head()
#combined = data_03_03.groupby('Country').sum()
data_03_03.loc['China']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'China'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-71d95c2d1e68> in <module>
#       1 data_03_03.head()
#       2 #combined = data_03_03.groupby('Country').sum()
# ----> 3 data_03_03.loc['China']
#
# ...

# %%
un_population_total = un_population.query('Time == 2019')[['Location', 'PopTotal']].set_index('Location')

# %%
data_03_03.set_index('Country').join(un_population_total).sort_values('New_cases', ascending=False)
# Out:
#          Date_reported Country_code WHO_region  New_cases  Cumulative_cases  \
# China       2020-02-13           CN       WPRO      15152             59882
# China       2020-02-14           CN       WPRO       4050             63932
# China       2020-02-05           CN       WPRO       3892             24363
# China       2020-02-06           CN       WPRO       3697             28060
# China       2020-02-08           CN       WPRO       3387             34598
# ...                ...          ...        ...        ...               ...
# Cambodia    2020-01-28           KH       WPRO         -4                 1
# Viet Nam    2020-01-25           VN       WPRO         -4                 2
# Thailand    2020-02-05           TH      SEARO         -4                25
# Thailand    2020-02-01           TH      SEARO         -4                19
# Tunisia     2020-03-03           TN       EMRO         -5                 0
#
# ...
